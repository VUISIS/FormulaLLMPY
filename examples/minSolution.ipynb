# %%
import formulallm.formula as f

# %%
f.load("./data/MappingExample.4ml")
# Out:
# (Compiled) MappingExample.4ml
# 0.59s.
# 'domain Mapping\n{\n  Component ::= new (id: Integer, utilization: Real).\n  Processor ::= new (id: Integer).\n  Mapping   ::= new (c: Component, p: Processor).\n\n  // The utilization must be > 10\n  invalidUtilization :- c is Component, c.utilization <= 10.\n\n  badMapping :- p is Processor, \n\t\ts = sum(0.0, { c.utilization |\n\t\t\t       c is Component, Mapping(c, p) }), s > 100.\n\n  conforms no badMapping, no invalidUtilization.\n}\n\npartial model pm of Mapping\n{\n  c1 is Component(0, x).\n  c2 is Component(1, y).\n  p1 is Processor(0).\n  p2 is Processor(1).\n  Mapping(c1, p1).\n  Mapping(c2, p1).\n}'

# %%
f.solve("pm","1","Mapping.conforms")
# Out:
# Parsing text took: 1
# Visiting text took: 0
# Started solve task with Id 0.
# 0.07s.

# %%
f.constraints("0","0","0")
# Out:
# ---------------------------------------------------------------------------
# DllNotFoundException                      Traceback (most recent call last)
# DllNotFoundException: Unable to load shared library 'libz3' or one of its dependencies. In order to help diagnose loading problems, consider using a tool like strace. If you're using glibc, consider setting the LD_DEBUG environment variable:
# /usr/lib/dotnet/shared/Microsoft.NETCore.App/8.0.5/libz3.so: cannot open shared object file: No such file or directory
# /home/zhang0311/.dotnet/tools/.store/vuisis.formula.x64/1.0.0/vuisis.formula.x64/1.0.0/tools/net8.0/any/libz3.so: cannot open shared object file: No such file or directory
# /usr/lib/dotnet/shared/Microsoft.NETCore.App/8.0.5/liblibz3.so: cannot open shared object file: No such file or directory
# /home/zhang0311/.dotnet/tools/.store/vuisis.formula.x64/1.0.0/vuisis.formula.x64/1.0.0/tools/net8.0/any/liblibz3.so: cannot open shared object file: No such file or directory
# ...
