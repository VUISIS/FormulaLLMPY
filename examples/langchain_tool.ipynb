# %%
from langchain.pydantic_v1 import BaseModel, Field
from langchain.tools import BaseTool, StructuredTool, tool

# %%
import formulallm.formula as f

def execute_function(taskID: int):
    f.dir()

execute = StructuredTool.from_function(
    func=execute_function,
    name="execute",
    description="execute the formula code",
)

# %%
print(execute.name)
print(execute.description)
print(execute.args)
